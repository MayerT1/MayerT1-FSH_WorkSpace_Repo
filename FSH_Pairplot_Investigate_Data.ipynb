# %% [markdown]
# <a href="https://colab.research.google.com/github/MayerT1/MayerT1-FSH_WorkSpace_Repo/blob/master/FSH_Pairplot_Investigate_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
from google.colab import drive
drive.mount('/content/mnt')
nb_path = '/content/notebooks'
#create a symbolic link for pointing to /content/mnt/My Drive/Colab Notebooks
os.symlink('/content/mnt/My Drive/Colab Notebooks', nb_path)
sys.path.insert(0, nb_path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/mnt

# %%
# %cd /content/notebooks/
# !ls

# %%
from google.colab import files

import seaborn as sns

import pandas as pd
from pandas import DataFrame

import numpy as np
from numpy import random

# %% [markdown]
# # Dataframe

# %%
df = pd.read_csv('20100923_LaosData.csv')
display(df)
##describe
df.describe()
##hightlight max
#df_boston.loc[df_boston.idxmax().unique()].style.highlight_max()
df.style.highlight_max()
# Out:
#     ID          ba  ...  Mean_NDVI_Texture72  Mean_NDVI_Texture82
# 0    1    2.034531  ...           115.666667            21.666667
# 1    2    2.971091  ...           146.000000            41.666667
# 2    3    2.945627  ...           132.333333            26.666667
# 3    4    3.151799  ...           155.666667            41.000000
# 4    5    4.169793  ...           172.333333            67.333333
# ..  ..         ...  ...                  ...                  ...
# 73  74   41.936533  ...           162.666667            97.000000
# 74  75   37.101340  ...           139.333333           104.666667
# 75  76   37.785373  ...           158.000000           129.666667
# 76  77   55.486850  ...           131.333333            96.000000
# 77  78  105.942770  ...           209.000000           153.000000
#
# [78 rows x 119 columns]
# <style  type="text/css" >
#     #T_8dc7a660_9919_11ea_9748_0242ac1c0002row0_col13 {
#             background-color:  yellow;
# ...

# %%
list(df.columns.values)
# Out:
# RangeIndex(start=0, stop=78, step=1)

# %% [markdown]
# # BA and Volume

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
#iris = sns.load_dataset("iris")
g = sns.pairplot(df, kind="reg", vars=["ba", "volume"])

# %% [markdown]
# # ALOS

# %%
alos_df = df.loc[:, "Mean_ALOS_BAND1": "Mean_ALOS_BAND4"]
display(alos_df)
a = sns.pairplot(alos_df, kind="reg")
# Out:
#     Mean_ALOS_BAND1  Mean_ALOS_BAND2  Mean_ALOS_BAND3  Mean_ALOS_BAND4
# 0        107.666667        89.000000        72.333333        78.666667
# 1        107.333333        89.333333        70.333333        90.333333
# 2        107.666667        89.333333        73.000000        84.333333
# 3        105.666667        84.333333        64.666667        83.000000
# 4        104.666667        84.666667        63.333333        87.333333
# ..              ...              ...              ...              ...
# 73       100.333333        76.666667        51.000000        91.666667
# 74        99.666667        76.333333        49.000000        98.000000
# 75        97.666667        72.333333        44.666667        95.666667
# 76        98.666667        73.000000        46.000000        91.333333
# 77        96.500000        70.000000        43.500000        88.000000
#
# [78 rows x 4 columns]

# %% [markdown]
# # NDVI

# %%
mean_ndvi_df = df.loc[:, "Mean_NDVI": "Mean_NDVI_Texture8"]
display(mean_ndvi_df)
ndvi = sns.pairplot(mean_ndvi_df, kind="reg")
# Out:
#      Mean_NDVI  Mean_NDVI_Texture1  ...  Mean_NDVI_Texture7  Mean_NDVI_Texture8
# 0   156.000000            4.000000  ...          115.666667           21.666667
# 1   173.333333            2.666667  ...          146.000000           41.666667
# 2   163.000000            4.666667  ...          132.333333           26.666667
# 3   172.666667            2.666667  ...          155.666667           41.000000
# 4   180.333333            4.666667  ...          172.333333           67.333333
# ..         ...                 ...  ...                 ...                 ...
# 73  206.000000            6.666667  ...          162.666667           97.000000
# 74  215.666667            1.333333  ...          139.333333          104.666667
# 75  222.000000            3.333333  ...          158.000000          129.666667
# 76  215.000000            4.666667  ...          131.333333           96.000000
# 77  217.000000            0.000000  ...          209.000000          153.000000
#
# ...

# %% [markdown]
# # PCA

# %%
pca_df = df.loc[:, "Mean_PCA_Texture1": "Mean_PCA_Texture8"]
display(pca_df)
pca = sns.pairplot(pca_df, kind="reg")
# Out:
#     Mean_PCA_Texture1  Mean_PCA_Texture2  ...  Mean_PCA_Texture7  Mean_PCA_Texture8
# 0            0.000000           7.000000  ...         252.666667          12.000000
# 1            0.000000           7.333333  ...         241.000000          11.333333
# 2            0.000000           8.333333  ...         210.000000          10.000000
# 3            0.333333           7.666667  ...         229.000000          10.666667
# 4            0.000000           7.000000  ...         255.000000          12.000000
# ..                ...                ...  ...                ...                ...
# 73           0.333333           8.666667  ...         160.666667           5.666667
# 74           0.000000           8.333333  ...         219.666667          10.333333
# 75           0.000000           7.333333  ...         214.666667           6.000000
# 76           0.000000           8.666667  ...         179.333333           5.000000
# ...

# %% [markdown]
# # HF

# %%
hf_df = df.loc[:, "Mean_HsubtrHFP9": "Mean_CIR_OriBand3"]
display(hf_df)
hf = sns.pairplot(hf_df, kind="reg")
# Out:
#     Mean_HsubtrHFP9  Mean_CIR_OriBand1  Mean_CIR_OriBand2  Mean_CIR_OriBand3
# 0          2.358333          80.080000          70.485867          87.276900
# 1          0.895333          87.601667          68.202900          88.028300
# 2          2.283333          83.198500          72.107100          88.703333
# 3          0.955667          82.336267          63.163967          83.466033
# 4          2.861000          86.825400          63.370000          84.682700
# ..              ...                ...                ...                ...
# 73         3.035667          90.915633          51.347100          76.543967
# 74         1.858667          97.168800          49.430600          76.260833
# 75         2.498667          95.811633          45.051033          72.613133
# 76         2.507333          89.813367          45.615200          71.048533
# 77         2.998000          88.943450          42.837850          68.757800
#
# [78 rows x 4 columns]
